# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("schedule_summary.csv")
df.head(5)
# Out:
#          date   route_id  total_trips  early_am_trips  peak_am_trips  \
# 0  2019-10-05  CR-Lowell           16               0              3
# 1  2019-10-06  CR-Lowell           16               0              3
# 2  2019-10-12  CR-Lowell           16               0              3
# 3  2019-10-13  CR-Lowell           16               0              3
# 4  2019-10-19  CR-Lowell           16               0              3
#
#    midday_trips  peak_pm_trips  evening_pm_trips  late_pm_trips  local_trips  \
# 0             6              4                 2              1           16
# 1             6              4                 2              1           16
# 2             6              4                 2              1           16
# 3             6              4                 2              1           16
# 4             6              4                 2              1           16
#
#    express_trips  typical_trips  atypical_trips
# 0              0             16               0
# 1              0             16               0
# 2              0             16               0
# 3              0             16               0
# 4              0             16               0

# %%
latest_date = pd.to_datetime(df['date']).max()
latest_date
# Out:
# Timestamp('2022-08-10 00:00:00')

# %%
df['date'] = pd.to_datetime(df['date'])

filtered_df = df[df['date'] == latest_date]
filtered_df
# Out:
#             date          route_id  total_trips  early_am_trips  \
# 843   2022-08-10         CR-Lowell           43               4
# 1912  2022-08-10        CR-Needham           32               2
# 2613  2022-08-10       CR-Franklin           38               2
# 3835  2022-08-10       CR-Kingston           26               1
# 4831  2022-08-10      CR-Fairmount           47               5
# 5705  2022-08-10      CR-Fitchburg           34               1
# 6816  2022-08-10      CR-Greenbush           26               1
# 7803  2022-08-10      CR-Haverhill           45               2
# 8436  2022-08-10      CR-Worcester           42               4
# 9841  2022-08-10     CR-Providence           72               6
# 10758 2022-08-10    CR-Newburyport           57               4
# 11904 2022-08-10  CR-Middleborough           30               3
#
#        peak_am_trips  midday_trips  peak_pm_trips  evening_pm_trips  \
# 843                8            14              8                 7
# 1912               6            13              6                 4
# 2613               8            14              8                 4
# 3835               5            11              5                 2
# 4831               8            16              8                 8
# 5705               7            15              6                 4
# 6816               5            12              5                 2
# 7803              10            19              9                 4
# 8436               8            10             12                 5
# 9841              14            25             14                11
# 10758             10            24             10                 7
# 11904              5            10              5                 6
#
#        late_pm_trips  local_trips  express_trips  typical_trips  \
# 843                2           43              0             43
# 1912               1           31              1             32
# 2613               2            1             37             38
# 3835               2           24              2             26
# 4831               2           47              0             47
# 5705               1           30              4             34
# 6816               1           26              0             26
# 7803               1           23             22             45
# 8436               3           12             30              0
# 9841               2            3             69             72
# 10758              2           57              0             57
# 11904              1           30              0             30
#
#        atypical_trips
# 843                 0
# 1912                0
# 2613                0
# 3835                0
# 4831                0
# 5705                0
# 6816                0
# 7803                0
# 8436               42
# 9841                0
# 10758               0
# 11904               0

# %%
from google.colab import files

csv_file_path = 'latest_date_summary.csv'
filtered_df.to_csv(csv_file_path, index=False)
files.download(csv_file_path)
