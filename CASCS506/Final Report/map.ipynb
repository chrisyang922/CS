# %% [markdown]
# # We will be drawing the map of Boston University and plot the points where we intend to install water bottle stations.
#
# ## After running the file, the html file will be downloaded, which is the visualization.

# %%
candidate_lat_long = {
    "15 ST. MARY'S STREET": (42.3494,-71.1073),
    '910 COMMONWEALTH AVENUE': (42.3510,-71.1167),
    '213 BAY STATE ROAD': (42.3508,-71.1031),
    '163-179 AMORY STREET': (42.3185,-71.1013),
    '10 BUICK STREET': (42.3522,-71.1157),
    '619 MEMORIAL DRIVE': (42.3532,-71.1078),
    '975 COMMONWEALTH AVENUE': (42.3521,-71.1201),
    '580 COMMONWEALTH AVENUE':(42.3489,-71.0989),
    '949 COMMONWEALTH AVENUE':(42.3520,-71.1187),
    '602 COMMONWEALTH AVENUE':(42.3489,-71.1009),
    '10 LENOX STREET': (42.3351,-71.0791),
    '677 BEACON STREET': (42.3481,-71.0986),
    '540 COMMONWEALTH AVENUE':(42.3487,-71.0968),
    }

# %%
existing_lat_long = {
    '730 COMMONWEALTH AVENUE' : (42.3497,-71.1075),
    "8 ST. MARY'S STREET" : (42.3492,-71.1061),
    '25 BUICK STREET' : (42.3516,-71.1156),
    '855 COMMONWEALTH AVENUE' : (42.3511,-71.1146),
    '871 COMMONWEALTH AVENUE' : (42.3512,-71.1149),
    '700 COMMONWEALTH AVENUE' : (42.3495,-71.1041),
    '1019 COMMONWEALTH AVENUE' : (42.3521,-71.1215),
    '91 BAY STATE ROAD' : (42.3503,-71.0970),
    '275 BABCOCK STREET' : (42.3531,-71.1205),
    '33 HARRY AGGANIS WAY' : (42.3533,-71.1178),
    '925 COMMONWEALTH AVENUE':(42.3522,-71.1177),
    '517-521 BEACON STREET': (42.3505,-71.0906),
    '48-52 CUMMINGTON MALL': (42.3486,-71.1026),
    '808 COMMONWEALTH AVENUE': (42.3501,-71.1114),
    '575 COMMONWEALTH AVENUE': (42.3494,-71.0986),
    '273 BABCOCK STREET': (42.3525,-71.1198),
    '277 BABCOCK STREET': (42.3535,-71.1206),
    '640 COMMONWEALTH AVENUE': (42.3489,-71.1023),
    '890 COMMONWEALTH AVENUE': (42.3517,-71.1226),
    '915 COMMONWEALTH AVENUE': (42.3518,-71.1165),
    '610 BEACON STREET': (42.3497,-71.0944),
    '512 BEACON STREET': (42.3508,-71.0899),
    '140 Bay State Road': (42.3500,-71.0998),
    '100 ASHFORD STREET': (42.3546,-71.1235),
    '120 ASHFORD STREET': (42.3543,-71.1239),
    '704 COMMONWEALTH AVENUE': (42.3497,-71.1052),
    }

ryanBuildingsLongLat = {
    '700 BEACON STREET' : (42.3486722,-71.0982206),
    '154 BAY STATE ROAD' : (42.3501426,-71.1006783),
    '111 CUMMINGTON MALL' : (42.3490908,-71.1041456),
    '765 COMMONWEALTH AVENUE' : (42.3510643,-71.1075071),
    '565 COMMONWEALTH AVENUE' : (42.3494578,-71.098105),
    '44 CUMMINGTON MALL' : (42.3485404,-71.1028457),
    '110-112 CUMMINGTON MALL' : (42.3485174,-71.101787),
    '675 - 725 COMMONWEALTH AVENUE' : (42.3501003,-71.1038376),
    '750 COMMONWEALTH AVENUE' : (42.3497962,-71.1080312),
    '735 COMMONWEALTH AVENUE' : (42.3506624,-71.1064383),
    '226 BAY STATE ROAD' : (42.3504456,-71.1036861),
    '225 BAY STATE ROAD' : (42.3509191,-71.1036358),
    '64-86 CUMMINGTON MALL' : (42.3487282,-71.1035375),
    '617-621 COMMONWEALTH AVENUE' : (42.3497287,-71.1011687),
    '233 BAY STATE ROAD' : (42.3508609,-71.1038666),
    '156 BAY STATE ROAD' : (42.3501514,-71.100764),
    '195-197 BAY STATE ROAD' : (42.3506966,-71.1022823),
    '627-629 COMMONWEALTH AVENUE' : (42.3491895,-71.10131),
    '96-100 CUMMINGTON MALL' : (42.3488883,-71.1048443),
    '881 COMMONWEALTH AVENUE' : (42.3513856,-71.1155187),
    '100 BAY STATE ROAD' : (42.3497623,-71.0979673),
    '928 COMMONWEALTH AVENUE' : (42.3511896,-71.117814),
    '985 COMMONWEALTH AVENUE' : (42.3520969,-71.1200753),
    '888 COMMONWEALTH AVENUE' : (42.3507339,-71.115618),
    '820 COMMONWEALTH AVENUE' : (42.3504934,-71.1120347),
    '196 BAY STATE ROAD' : (42.3503165,-71.1023936),
    '300 BABCOCK STREET' : (42.353959,-71.120916),
    '2 CUMMINGTON MALL' : (42.348282,-71.100914),
    '30-38 CUMMINGTON MALL' : (42.3484364,-71.102308),
    '3 - 5 CUMMINGTON MALL' : (42.3486511,-71.1012653),
    '24 CUMMINGTON MALL' : (42.3483655,-71.1015899),
    '771 COMMONWEALTH AVENUE' : (42.3509964,-71.1079952),
    '775 COMMONWEALTH AVENUE' : (42.3509712,-71.108979),
    '1 UNIVERSITY ROAD' : (42.3510171,-71.1098134),
    '745 - 755 COMMONWEALTH AVENUE' : (42.3505236,-71.107545),
    '264-270 BAY STATE ROAD' : (42.3507823,-71.1052402),
    '635 COMMONWEALTH AVENUE' : (42.3498642,-71.1020204),
    '2 SILBER WAY' : (42.3496261,-71.1005877),
    '595 COMMONWEALTH AVENUE' : (42.3496397,-71.0997323),
    '285 BABCOCK STREET' : (42.3527669,-71.1211772),
    '590 COMMONWEALTH AVENUE' : (42.3484489,-71.1001558),
    '722-26-28 COMMONWEALTH AVENUE' : (42.3496292,-71.1059547)
}

newCoordinates = {}
for building, coordinates in ryanBuildingsLongLat.items():
    rounded_lat = round(coordinates[0], 4)
    rounded_lon = round(coordinates[1], 4)
    existing_lat_long[building] = (rounded_lat, rounded_lon)

# %%
finalized_lat_long = {
    '736 - 738 COMMONWEALTH AVENUE': (42.3498,-71.1072),
    '232 BAY STATE ROAD': (42.3505,-71.1039),
    '514-522 PARK DRIVE': (42.3481,-71.1063)
}

# %%
nonexisting_lat_long = {
    '204 BAY STATE ROAD': (42.3503,-71.1027),
    '100 MOUNTFORT STREET': (42.3482,-71.1051),
    '209 BAY STATE ROAD' : (42.3507,-71.1029),
    '200-202 BAY STATE ROAD' : (42.3503,-71.1026),
    '184 BAY STATE ROAD' : (42.3503,-71.1019),
    '190 BAY STATE ROAD' : (42.3503,-71.1021),
    '161 BAY STATE ROAD' : (42.3506,-71.1008),
    '163 BAY STATE ROAD' : (42.3506,-71.1009),
    '159 BAY STATE ROAD' : (42.3506,-71.1008),
    '6 BUSWELL STREET' : (42.3477,-71.1040),
    '22 BUSWELL STREET' : (42.3476,-71.1048),
    '96 MOUNTFORT STREET' : (42.3481,-71.1050),
    '806-820 BEACON STREET' : (42.3476,-71.1022),
    '844 BEACON STREET' : (42.3474,-71.1036),
    '46 MOUNTFORT STREET' : (42.3477,-71.1033),
    '856-862 BEACON STREET' : (42.3472,-71.1040),
    '870-872 BEACON STREET' : (42.3467,-71.1043),
    '824-826 BEACON STREET' : (42.3476,-71.1027),
    '24 BUSWELL STREET' : (42.3476,-71.1049),
    '16 ARUNDEL STREET' : (42.3477,-71.1037),
    '834-836 BEACON STREET' : (42.3475,-71.1031),
    '830 BEACON STREET' : (42.3475,-71.1029),
    '98 MOUNTFORT STREET' : (42.3481,-71.1050),
    '1010 COMMONWEALTH AVENUE' : (42.3513,-71.1212),
    '930-940 COMMONWEALTH AVENUE' : (42.3512,-71.1178),
    '186 BAY STATE ROAD' : (42.3503,-71.1020),
    '900 COMMONWEALTH AVENUE' : (42.3511,-71.1175),
    '38 BUSWELL STREET' : (42.3472,-71.1060),
    '44 BUSWELL STREET' : (42.3470,-71.1064),
    '48 BUSWELL STREET' : (42.3470,-71.1066),
    '1053 BEACON STREET' : (42.3477,-71.1016),
    '483 COMMONWEALTH AVENUE' : (42.3487,-71.0944),
    '2 BUSWELL STREET' : (42.3478,-71.1038),
    '210-212 BAY STATE ROAD' : (42.3504,-71.1030),
    '90-92 BAY STATE ROAD' : (42.3499,-71.0970),
    '30 HARRY AGGANIS WAY' : (42.3527,-71.1184),
    '17 BUSWELL STREET' : (42.3477,-71.1053),
    '35 BUSWELL STREET': (42.3475,-71.1064),
    '187 BAY STATE ROAD': (42.3507,-71.1019),
    '710 COMMONWEALTH AVENUE': (42.3496,-71.1055),
    '25 ABERDEEN STREET': (42.3460,-71.1037),
    '515 PARK DRIVE': (42.3480,-71.1056),
    '171 BAY STATE ROAD': (42.3506,-71.1013),
    '278 BABCOCK STREET': (42.3534,-71.1219),
    '81 BAY STATE ROAD': (42.3503,-71.0966),
    '34 BUSWELL STREET': (42.3471,-71.1062),
    '112 BAY STATE ROAD': (42.3502,-71.1000),
    '135 BAB STATE ROAD': (42.3502,-71.1002),
    '139 BAY STATE ROAD': (42.3503,-71.0992),
    '31 BUSWELL STREET': (42.3475,-71.1062),
    '500-504 PARK DRIVE': (42.3472,-71.1057),
    '32 HARRY AGGANIS WAY': (42.3525,-71.1186),
    '11 BUSWELL STREET': (42.3479,-71.1050),
    '41 BUSWELL STREET': (42.3474,-71.1064),
    '50-52 BUSWELL STREET': (42.3472,-71.1063),
    '80-82 IVY STREET': (42.3859,-71.1335),
    '3 BUSWELL STREET': (42.3480,-71.1042),
    '29 BUSWELL STREET': (42.3475,-71.1061),
    '43 BUSWELL STREET': (42.3474,-71.1067),
    '55 BUSWELL STREET': (42.3474,-71.1070),
    '1A BUSWELL STREET': (42.3480,-71.1044),
    '15 BUSWELL STREET': (42.3477,-71.1053),
    '33 BUSWELL STREET': (42.3475,-71.1063),
    '79 BAY STATE ROAD': (42.3503,-71.0965),
    '2 RALEIGH STREET': (42.3501,-71.0954),
    '481 COMMONWEALTH AVENUE': (42.3487,-71.0944),
    '94 BAY STATE ROAD': (42.3499,-71.0971),
    '192 BAY STATE ROAD': (42.3503,-71.1022),
    '153 BAY STATE ROAD': (42.3506,-71.1005),
    '164 BAY STATE ROAD': (42.3502,-71.1010),
    '167-169 BAY STATE ROAD': (42.3506,-71.1011),
    '158-162 BAY STATE ROAD': (42.3502,-71.1008),
    '176 BAY STATE ROAD': (42.3502,-71.1016),
    '175 BAY STATE ROAD': (42.3506,-71.1014),
    '166-168 BAY STATE ROAD': (42.3502,-71.1011),
    '182 BAY STATE ROAD': (42.3503,-71.1018),
    '208 BAY STATE ROAD': (42.3504,-71.1029),
    '206 BAY STATE ROAD': (42.3503,-71.1028),
    '198 BAY STATE ROAD': (42.3503,-71.1025),
    '916-922 COMMONWEALTH AVENUE' : (42.3508, -71.1165),
    '866 BEACON STREET' : (42.3470, -71.1042),
    '714 COMMONWEALTH AVENUE' : (42.3496, -71.1056),
    '531 BEACON STREET' : (42.3471, -71.1033),
    '180 BAY STATE ROAD' : (42.3502517, -71.1017276),
    '830-846 COMMONWEALTH AVENUE' : (42.3505, -71.1119),
    '24 COTTAGE FARM ROAD' : (42.3487, -71.11322),
    '828 BEACON STREET' : (42.3462, -71.1056),
    '40 BUSWELL STREET' : (42.3472, -71.10615),
    '152 BAY STATE ROAD' : (42.3501, -71.1005),
    '138 MOUNTFORT STREET' : (42.3484, -71.1066),
    '76 BAY STATE ROAD' : (42.3498, -71.0964),
    '27 ABERDEEN STREET' : (42.3458, -71.1036),
    '236 BAY STATE ROAD' : (42.3505, -71.1041),
    '128 BAY STATE ROAD' : (42.3500, -71.0990),

    '194 BAY STATE ROAD' : (42.3503, -71.1023),

    '457 PARK DRIVE' : (42.3458, -71.1045),
    '455 PARK DRIVE' : (42.3458, -71.1045),
    '147 BAY STATE ROAD' : (42.3505, -71.1000),
    '172 BAY STATE ROAD' : (42.3502, -71.1013),

    '56 BAY STATE ROAD' : (42.3497, -71.0955),
    '718 COMMONWEALTH AVENUE' : (42.3495, -71.1058),
    '124 BAY STATE ROAD' : (42.3499, -71.0988),
    '125 BAY STATE ROAD' : (42.3504, -71.0990),

    '708 COMMONWEALTH AVENUE' : (42.3495, -71.1053),
    '121 BAY STATE ROAD' : (42.3504, -71.0988),
    '185 BAY STATE ROAD' : (42.3506, -71.1018),
    '116 BAY STATE ROAD' : (42.3499, -71.0985),

    '61 BAY STATE ROAD' : (42.35020, -71.0956),
    '193 BAY STATE ROAD' : (42.3506, -71.1021),
    '10 COTTAGE FARM ROAD' : (42.3475, -71.1029),
    '78 BAY STATE ROAD' : (42.3498, -71.0964),
    '143 BAY STATE ROAD' : (42.3505, -71.0998),
    '135 IVY STREET' : (42.3860, -71.1333),
    '75 BAY STATE ROAD' : (42.3502, -71.0962),
    '74 BAY STATE ROAD' : (42.3498, -71.0963),
    '84 BAY STATE ROAD' : (42.3498, -71.0967),
    '118 BAY STATE ROAD' : (42.3499, -71.0986),
    '122 BAY STATE ROAD' : (42.3499, -71.0988),
    '50 WORTHINGTON ROAD' : (42.3347, -71.1017),
    '68-70 BAY STATE ROAD' : (42.3499, -71.0961),
    '177 BAY STATE ROAD' :(42.3010, -71.7844),
    '179 BAY STATE ROAD': (42.3506, -71.1015),
    '157 BAY STATE ROAD': (42.3505, -71.1006),
    '203 BAY STATE ROAD': (42.3507242, -71.1026),
    '181 BAY STATE ROAD': (42.3506, -71.1016),
    '173 BAY STATE ROAD': (42.3506, -71.1013),
    '178 BAY STATE ROAD': (42.3502, -71.1016),
    '205 BAY STATE ROAD': (42.3507, -71.1026),
    '42 BUSWELL STREET': (42.3472, -71.1061),
    '852 BEACON STREET': (42.3471, -71.1036),
    '848 BEACON STREET': (42.3473, -71.1036),
    '864 BEACON STREET': (42.3471, -71.1043),
    '133 BAY STATE ROAD': (42.3504, -71.0994),
    '625 COMMONWEALTH AVENUE': (42.3497, -71.1015),
    '832 BEACON STREET': (42.3473, -71.1029),
    '141 BAY STATE ROAD': (42.3501, -71.0976),
    '117 BAY STATE ROAD': (42.3502, -71.1000),
    '53 BAY STATE ROAD': (42.3501, -71.0951),
    '67 BAY STATE ROAD': (42.3500, -71.0959),
    '110 BAY STATE ROAD': (42.3499, -71.0983),
    '115 BAY STATE ROAD': (42.3504, -71.0985),
    '141 CARLTON STREET': (42.3485, -71.1087),
    '37-39 CARLTON STREET': (42.344, -71.1084),
    '1 BUSWELL STREET': (42.3479, -71.1044),
    '5 BUSWELL STREET': (42.3479, -71.1044),
    '37 BUSWELL STREET': (42.3474, -71.1064),
    '39 BUSWELL STREET': (42.3474, -71.1065),
    '45 BUSWELL STREET': (42.3473, -71.1067),
    '47 BUSWELL STREET': (42.3473, -71.1068),
    '7 BUSWELL STREET': (42.3479, -71.1048),
    '60 BAY STATE ROAD': (42.3497, -71.0957),
    '80 BAY STATE ROAD': (42.3498, -71.0965),
    '191 BAY STATE ROAD': (42.3506, -71.1021),
    '199 BAY STATE ROAD': (42.3507, -71.1024),
    '201 BAY STATE ROAD': (42.3507, -71.1025),
    '214 BAY STATE ROAD': (42.3503, -71.1031),
    '207 BAY STATE ROAD': (42.3507, -71.1027),
    '188 BAY STATE ROAD': (42.3502, -71.1020),
}

# %%
locations = {
    "15 ST. MARY'S STREET": (42.3494,-71.1073),
    '910 COMMONWEALTH AVENUE': (42.3510,-71.1167),
    '213 BAY STATE ROAD': (42.3508,-71.1031),
    '163-179 AMORY STREET': (42.3185,-71.1013),
    '10 BUICK STREET': (42.3522,-71.1157),
    '619 MEMORIAL DRIVE': (42.3532,-71.1078),
    '975 COMMONWEALTH AVENUE': (42.3521,-71.1201),
    '580 COMMONWEALTH AVENUE':(42.3489,-71.0989),
    '949 COMMONWEALTH AVENUE':(42.3520,-71.1187),
    '602 COMMONWEALTH AVENUE':(42.3489,-71.1009),
    '10 LENOX STREET': (42.3351,-71.0791),
    '677 BEACON STREET': (42.3481,-71.0986),
    '540 COMMONWEALTH AVENUE':(42.3487,-71.0968),
}

# List of addresses ordered as per the user's dictionary
ordered_addresses = [
    "15 ST. MARY'S STREET",
    '910 COMMONWEALTH AVENUE',
    '213 BAY STATE ROAD',
    '163-179 AMORY STREET',
    '10 BUICK STREET',
    '619 MEMORIAL DRIVE',
    '975 COMMONWEALTH AVENUE',
    '580 COMMONWEALTH AVENUE',
    '949 COMMONWEALTH AVENUE',
    '602 COMMONWEALTH AVENUE',
    '10 LENOX STREET',
    '677 BEACON STREET',
    '540 COMMONWEALTH AVENUE'
]

# %% [markdown]
# 1. Green Points are the locations where we intend to install water bottle stations.
#
# 2. Blue Points are the locations where water bottle stations already exist.
#
# 3. Gray Points are the locations where we do not intend to install water bottle stations and leave as it is.

# %%
import folium
from folium.plugins import FloatImage
from matplotlib.colors import to_hex
import numpy as np



radius = 10
# Create a map centered around the first location
map_center = existing_lat_long['675 - 725 COMMONWEALTH AVENUE']
map = folium.Map(location=map_center, zoom_start=15)

# Add circles for each location
for address, coords in finalized_lat_long.items():
    folium.Circle(
        location=coords,
        radius=15,  # radius in meters
        color='#00FF00',
        fill=True,
        fill_color='#00FF00',
        fill_opacity=1,
        popup=address
    ).add_to(map)

for address, coords in existing_lat_long.items():
    folium.Circle(
        location=coords,
        radius=radius,  # radius in meters
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.4,
        popup=address
    ).add_to(map)

for address, coords in candidate_lat_long.items():
    folium.Circle(
        location=coords,
        radius=15,  # radius in meters
        color='#00FF00',
        fill=True,
        fill_color='#00FF00',
        fill_opacity=1,
        popup=address
    ).add_to(map)

for address, coords in nonexisting_lat_long.items():
    folium.Circle(
        location=coords,
        radius=radius,  # radius in meters
        color='gray',
        fill=True,
        fill_color='gray',
        fill_opacity=0.4,
        popup=address
    ).add_to(map)

legend_html = '''
<div style="position: fixed;
            top: 10px; right: 50px; width: 200px; height: 130px;
            border:4px solid grey; z-index:9999; font-size:14px;
            ">
            &nbsp; <span style = "color: green;">Green : Locations to Install Water Bottle Stations </span> <br>
            &nbsp; <span style = "color: blue;">Blue : Existing Water Bottle Stations </span> <br>
            &nbsp; <span style = "color: gray;">Gray : Locations to Not Install Water Bottle Stations </span>
</div>
'''


# Add the legend to the map
legend = folium.Element(legend_html)
map.get_root().html.add_child(legend)


# Show the map
map.save("Boston_Map_final.html")
"Boston_Map.html"
# Out:
# 'Boston_Map.html'
